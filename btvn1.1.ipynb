# %%
for i in range(10):
    print("90",end="")
# Out:
# 90909090909090909090

# %%
n=input("nhập số")
n=2*int(n)
print(n)
# Out:
# 10

# %%
a=input("chiều rộng:")
b=input("chiều dài:")
r=int(a)//2
dtcl=int(a)*int(b)-3.14*int(r)*int(r)
print("diện tích còn lại:",dtcl)
# Out:
# diện tích còn lại: 12.44

# %%
x = int(input("nhập 1 số"))
s = 'chẵn' if x % 2 == 0 else 'lẻ'
print(s)  # lẻ
# Out:
# chẵn

# %%
x=input("nhập chữ cái in thường a-z:")
viet_thuong=x
viet_hoa=x.upper()
if x == viet_thuong:
    print(viet_hoa)
elif(x == viet_hoa):
    print(viet_thuong)
# Out:
# DÀAFAF

# %%
x=input("nhập 1 chữ")
vt=x
vh=x.upper()
if x == vt:
    print("là ký tự alphabet")
elif x == vh:
    print("là ký tự alphabet")
print(x)
# Out:
# là ký tự alphabet
# j

# %%
x=input("nhập chữ cái in thường a-z:")
viet_thuong=x
viet_hoa=x.upper()
if x == viet_thuong:
    print(viet_hoa)
elif(x == viet_hoa):
    print(viet_thuong)

# %%
a=input("cạnh thứ nhất")
b=input("cạnh thứ hai")
c=input("cạnh thứ ba")
if int(a)+int(b)>int(c) or int(a)+int(c)>int(b) or int(b)+int(c)>int(a):
    print("đây là 3 cạnh của tam giác")
if int(a)+int(b)<=int(c) or int(a)+int(c)<=int(b) or int(b)+int(c)<=int(a):
    print("đây không phải là 3 cạnh của tam giác")
p=int(a)/2 +int(b)/2 +int(c)/2
s=(p*(p-int(a)))*(p-int(b))*(p-int(c))**0.5
print("diện tích tam giác là",s)
# Out:
# đây là 3 cạnh của tam giác
# diện tích tam giác là 261.4808340251729

# %%
ki_tu=["a","s","d","f","g","h","j","k","l","q","w","e","r","t","y","u","i","o","p","z"]
print(ki_tu[4],ki_tu[8])
# Out:
# g l

# %%
name =input("tên chủ hô")
print(f"tên chủ hộ:{name}")
a = input("chỉ số tháng trước")
b = input("chỉ số tháng này")
a = int(a)
b = int(b)
c = int(c)
if 0<(b-a)<=50:
    pass
else:
    c=1984
if 51<=(b-a)<=100:
    pass
else:    c=2050
if 100<=(b-a)<=200:
    pass
else:
    c=2380
if 201<=(b-a)<=300:
    pass
else:
    c=2998
if 301<=(b-a)<=400:
    pass
else:    c=3350
if 401<=(b-a):
    pass
else:    c=3460
tien1 = ((b - a) * c) * (1 + 8/100)
print("số tiền phải trả là", tien1)
# Out:
# tên chủ hộ:abc
# số tiền phải trả là 1121040.0

# %%
n=int(input("nhập 1 số nguyên"))
if n%2==0:
    print("số chẵn")
else:    print("số lẻ")
# Out:
# số lẻ

# %%
n=int(input("nhập 1 số"))
if n%5==0 and n%10!=0:
    print("True")
else:    print("false")
# Out:
# True

# %%
n=int(input("nhập 1 số nguyên"))
if n%5==0 and n%3==0:
 print("True")
else:print("False")
# Out:
# True

# %%
ns=input("nhập năm sinh")
n=int(ns)
du_tuoi=2026-n
if du_tuoi>=18:
    print("bạn đủ điều kiện đi bầu cử")
else:
    print("bạn chưa đủ điều kiện đi bầu cử")
# Out:
# bạn chưa đủ điều kiện đi bầu cử

# %%
a=int(input("nhập số thứ nhất"))
b=int(input("nhập số thứ hai"))
if a>b:
    print(a)
if b>a:
 print(b)
if a==b:
   print("hai số bằng nhau")
# Out:
# hai số bằng nhau

# %%
n=int(input("nhập 1 kí tự"))
if n==(n):
    print("đây là số ")
else:print("đây là chữ")
# Out:
# đây là số

# %%
nd=int(input(("nhập điểm")))
if nd>=8:
    print("điểm của bạn là giỏi")
elif 6.5<=nd<8:
    print("điểm của bạn là khá")    
elif 5<=nd<6.5:
    print("điểm của bạn là trung bình")
elif nd<5:
    print("điểm của bạn là yếu")
# Out:
# điểm của bạn là yếu

# %%
nn=int(input("nhập năm"))
if nn%400==0 or nn%4==0 and nn%100!=0:
    print("năm này là năm nhuận")
else:
    print("năm này không phải là năm nhuận")
# Out:
# năm này là năm nhuận

# %%
def numbers(a):
    match a:
        case 0:
            print("không")
        case 1:
            print("một")
        case 2:
            print("hai")
        case 3:
            print("ba")
        case 4:
            print("bốn")
        case 5:
            print("năm")
        case 6:
            print("sáu")
        case 7:
            print("bảy")
        case 8:
            print("tám")
        case 9:
            print("chín")
a=int(input("nhập 1 số: "))
numbers(a)
# Out:
# một

# %%
a=int(input("nhập điểm"))
if a>=4:
 print("qua môn")
else:
 print("trượt môn")
# Out:
# trượt môn

# %%
a=int(input("nhập năm sinh"))
t=2025-a
if t>=18:
    print("bạn đủ 18 tuổi")
else: 
    print("bạn chưa đủ 18 tuổi")
print(f"tuổi của bạn là: {t}")
# Out:
# bạn chưa đủ 18 tuổi
# tuổi của bạn là: 14
