# %%
a=int(input())
b=(a*(a+1))/2
print("Tổng từ 1 đến n là:",b)
# Out:
# Tổng từ 1 đến n là: 465.0

# %%
a=int(input())
if a<0:
    print("Không phải số dương")
if a>0 and a%2!=0 and a%3!=0 and a%5!=0 and a%7!=0:
    print("là số nguyên tố")
else:print("Không phải số nguyên tố")
# Out:
# là số nguyên tố

# %%
n=int(input())
kq=1
for k in range(1,n+1):
    kq*=k
print(kq)
# Out:
# 720

# %%
n=int(input("Nhập số"))
so=[[k for k in range(1,n+1)]]
so=map(int,input().split())
for n in so:
    if n==42:
     print("I have found the meaning of life!")
    else:print("It is a joke")
# Out:
# It is a joke

# %%
a,b=map(int,input().split())
def ns(a,b):
 for k in range(a,b):
  if k>1 and k%2!=0 and k%3!=0 and k%5!=0 and k%7!=0:
   print(k)
  if 1<k<10 and k!=4 and k!=6 and k!=8 and k!=9:
   print(k)
ns(a,b)
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       7    print(k)
#       8    sum(k)
# ----> 9 ns(a,b)
#
# Cell In[18], line 8, in ns(a, b)
#       6 if 1<k<10 and k!=4 and k!=6 and k!=8 and k!=9:
#       7  print(k)
# ----> 8  sum(k)
#
# TypeError: 'int' object is not iterable

# %%
a = int(input())
b = int(input())
  
  
if a>b:
 print("So thu nhat lon hon so thu hai!")
else:   
    tong = 0
    for i in range(a, b+1):
        tong += i
print(tong)
# Out:
# 6

# %%
def thang(n):
    match n:
     case "1" | "3" |"5" |"7":
      return "Tháng có 31 ngày"
# Out:
# None

# %%
n=int(input())
def ns(n):
  if n==0:
    return False
  while n%2==0:
    n//=2
  return n==1
print(ns(n))
# Out:
# True
