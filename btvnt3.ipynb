# %%
a,b=map(int,input("nhập chiều dài và chiều rộng").split())
s=a*b
c=(a+b)*2
print("diện tích hình chữ nhật là",s)
print("chu vi hình chữ nhật là",c)
# Out:
# diện tích hình chữ nhật là 12
# chu vi hình chữ nhật là 14

# %%
a=int(input("nhập bán kính"))
s=3.14*a*a
c=2*3.14*a
print("diện tích hình tròn là",s)
print("chu vi hình tròn là",f"{c:.2f}")
# Out:
# diện tích hình tròn là 314.0
# chu vi hình tròn là 62.80

# %%
a,b,c=map(int,input("nhập 3 số").split())
if a+b>c and a+c>b and b+c>a:
    print("3 số này là 3 cạnh của 1 tam giác")
else:
    print("3 số này không phải là 3 cạnh của 1 tam giác")
p=a+b+c
d=p/2
s=(d*(d-a)*(d-b)*(d-c))**0.5
if  a==b!=c or a==c!=b or b==c!=a:
    print("tam giác cân")
if a==b==c :
    print("tam giác đều")

if a**2==b**2+c**2 or b**2==a**2+c**2 or c**2==a**2+b**2:
    print("tam giác vuông")
p=a+b+c
d=p/2
s=(d*(d-a)*(d-b)*(d-c))**0.5
print("diện tích tam giác là",s if a+b>c and a+c>b and b+c>a else "Không thể tính ")
# Out:
# 3 số này là 3 cạnh của 1 tam giác
# tam giác đều
# diện tích tam giác là 3.897114317029974

# %%
a,b=map(int,input("ax+b=0").split())
x=-b/a
print("nghiệm của phương trình là",x)
# Out:
# nghiệm của phương trình là -2.0

# %%
a,b,c=map(int,input("ax2+bx+c=0").split())
d=b**2-4*a*c
if d<0:
    print("phương trình vô nghiệm")
if d>0:
     print("phương trình có 2 nghiệm phân biệt")
if d==0:
    print("phương trình có nghiệm kép")
x1=(-b+d**0.5)/(2*a) if d>=0 else "Không thể tính"
x2=(-b-d**0.5)/(2*a) if d>0 else ""
print("nghiệm của phương trình là",x1,x2)
# Out:
# phương trình có 2 nghiệm phân biệt
# nghiệm của phương trình là 2.618033988749895 0.3819660112501051

# %%
a,b,c,d=map(int,input().split())
so=[a,b,c,d]
soln=so[0]
for n in so:
    if n>soln:
     soln=n
print("số lớn nhất là:",soln)
# Out:
# số lớn nhất là: 6

# %%
a,b,c,d=map(int,input().split())
so=[a,b,c,d]
sonn=so[0]
for n in so:
    if n<sonn:
     sonn=n
print("số nhỏ nhất là :",sonn)
# Out:
# số nhỏ nhất là : 1

# %%
a,b,m,c,d,n=map(float,input("ax+by=m,cx+dy=n").split())
D=a*d-b*c
Dy=a*n-c*m
Dx=d*m-b*n
print(f" x={Dx/D} y={Dy/D}")
# Out:
#  x=-1.0 y=2.0

# %%
s=int(input("nhấp số giây"))
h=s/3600
gio=int(h)
p=(h-int(h))*60
phut=int(p)
s=(p-int(p))*60
giay=int(s)
print(f"{gio} giờ {phut} phút {giay} giây")
# Out:
# 1 giờ 36 phút 40 giây

# %%
a,b,r=map(int,input("nhập tâm").split())
x,y=map(int,input("nhập điểm").split())
kq=(x-a)**2+(y-b)**2-r**2
if kq==0:
 print("điểm thuộc đường tròn")
else:print("điểm ko thuộc đường tròn")
# Out:
# điểm thuộc đường tròn

# %%
x,y=map(int,input("x^y").split())
kq=x**y
print(kq)
# Out:
# 4

# %%
##############################################################

# %%
a=int(input())
line=[ k for k in range(1,a+1)]
for k in line:
    ki_tu="0"*k
    print(ki_tu)
# Out:
# 0
# 00
# 000
# 0000
# 00000

# %%
n=int(input())
def nhap_so(n):
 for k in range(1,(n)):
  if k>(n-1)/2 and n%2==1:
    return k-1
  if k>(n-1)/2 and n%2==0:
    return k
print(nhap_so(n))
# Out:
# 4

# %%
a=int(input())
hdv=a%10
khdv=int(a/10)
hc=int(khdv)%10
khc=int(khdv/10)
ht=int(khc)%10
kht=int(khc/10)
hn=int(kht)%10
print(f"{hdv}{hc}{ht}{hn}")
# Out:
# 9554

# %%
a,b=map(int,input().split())
print(f"{b} {a}")
# Out:
# 2 1

# %%
n=int(input())
def nhap_so(n):
    if n<=0:
       return False
    while n%2==0:
        n=n//2
    return n==1
print(nhap_so(n))
# Out:
# True

# %%
import math
m,n=map(int,input().split())
pc=m/n
print(math.floor(pc))
# Out:
# 0

# %%
import math
m,n=map(int,input().split())
pc=m/n
print(math.ceil(pc))
# Out:
# 52

# %%
a=int(input())
if a%2==0:
 print("Even")
else:print("Odd")
# Out:
# Even

# %%
a,b=map(int,input().split())
if a<0 and b<0:
    print("Yes")
else:print("No")
# Out:
# Yes

# %%
a,b=map(str,input().split())
if len(a)>len(b):
    print("True")
else:print("False")
# Out:
# False

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:print("No")
# Out:
# Yes

# %%
a,b,c,d=map(int,input().split())
so=[a,b,c,d]
soln=so[0]
for n in so:
    if n>soln:
      soln=n
print(soln)
# Out:
# 7

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
 if a==b==c:
  print("Tam giác đều")
 elif a==b or a==c or b==c:
  print("Tam giác cân")
 else: print("Tam giác thường")
else:print("Không phải tam giác")
# Out:
# Tam giác đều

# %%
n=int(input())
if n%4==0 and n%100!=0 or n%400==0:
    print("Năm nhuận")
else:print("Không phải năm nhuận")
# Out:
# Năm nhuận

# %%
a,b=map(float,input("ax+b=0").split())
def ns(a,b):
 if a==0:
  if b==0:
   print("Vô số nghiệm")
  else:
   print("Vô nghiệm")
 else:
   x=(-b)/a
   print(f"{x:.2f}")
ns(a,b)
# Out:
# Vô số nghiệm

# %%
x=float(input())
if x>=8:
 print("Giỏi")
if 8>x>=6.5:
  print("Khá")
if 6.5>x>=5:
  print("Trung bình")
if x<5:
 print("Yếu")
# Out:
# Khá

# %%
a=float(input())
b=int(a)
def ns(a):
    if a-b==0:
        print(b,b,b)
    elif a-b>0.5:
     print(b+1,b,b)
ns(a)
# Out:
# 9 9 9

# %%
a,b,c,d=map(int,input().split())
cb=b/a
if c==cb*b and d==cb*c:
    print("Cấp số nhân")
else:print("Không phải cấp số nhân")
# Out:
# Không phải cấp số nhân
